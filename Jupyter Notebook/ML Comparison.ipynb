# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import numpy as np

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# 70000 images in MNIST dataset
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
some_digit=x_train[810]
some_digit_image=some_digit.reshape(28,28)
plt.imshow(some_digit_image,cmap="binary")
plt.axis("off")
plt.show()

# %%
int(y_train[810])
# Out:
# 6

# %%
print("Size of the dataset:", len(x_train) + len(x_test))
print("Number of elements in the training set:", len(x_train))
print("Number of elements in the test set:", len(x_test))
# Out:
# Size of the dataset: 70000
# Number of elements in the training set: 60000
# Number of elements in the test set: 10000

# %%
(x_train,y_train),(x_test, y_test)=keras.datasets.mnist.load_data()
x_train=x_train.reshape(60000,784)
x_test=x_test.reshape(10000,784)

knn=KNeighborsClassifier(n_neighbors=3)

knn.fit(x_train, y_train)

y_pred=knn.predict(x_test)

accuracy=knn.score(x_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")

cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test accuracy: 0.9705

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

x_train=x_train.astype("float32") / 255.0
x_test=x_test.astype("float32") / 255.0
x_train=x_train.reshape(-1, 28 * 28)
x_test=x_test.reshape(-1, 28 * 28)

x_train,_,y_train,_ =train_test_split(x_train, y_train, train_size=10000, random_state=42, stratify=y_train)
x_test,_,y_test,_ =train_test_split(x_test, y_test, train_size=2000, random_state=42, stratify=y_test)

svm=SVC(kernel='linear',C=1.0,random_state=42)
svm.fit(x_train, y_train)

y_pred=svm.predict(x_test)

accuracy=accuracy_score(y_test, y_pred)
print(f"Test accuracy: {accuracy:.4f}")

cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

print("Size of the dataset:", len(x_train) + len(x_test))
print("Number of elements in the training set:", len(x_train))
print("Number of elements in the test set:", len(x_test))
# Out:
# Test accuracy: 0.9165
# Size of the dataset: 12000
# Number of elements in the training set: 10000
# Number of elements in the test set: 2000

# %%
some_digit=x_test[400]
some_digit_image=some_digit.reshape(28,28)
plt.imshow(some_digit_image,cmap="binary")
plt.axis("off")
plt.show()

# %%
int(y_pred[400])
# Out:
# 0

# %%
int(y_test[400])
# Out:
# 0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x_train_flat=x_train.reshape(x_train.shape[0], -1)
x_test_flat=x_test.reshape(x_test.shape[0], -1)

logreg=LogisticRegression(max_iter=1000)
logreg.fit(x_train_flat, y_train)

y_pred_logreg=logreg.predict(x_test_flat)

accuracy=logreg.score(x_test_flat,y_test)
print(f"Logistic Regression Test Accuracy: {accuracy:.4f}")

cm_logreg=confusion_matrix(y_test, y_pred_logreg)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_logreg, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Logistic Regression)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Test Accuracy: 0.9200

# %%
from sklearn.tree import DecisionTreeClassifier

(x_train,y_train),(x_test, y_test)=keras.datasets.mnist.load_data()

x_train=x_train.reshape(60000, 784)
x_test=x_test.reshape(10000, 784)

dt_classifier=DecisionTreeClassifier()

dt_classifier.fit(x_train, y_train)

y_pred=dt_classifier.predict(x_test)

accuracy=dt_classifier.score(x_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")

cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for Decision Tree")
plt.show()
# Out:
# Test accuracy: 0.8776

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# CNN Model(Final chosen for building further as it gives best accuracy)
x_train=x_train.astype("float32") / 255.0
x_test=x_test.astype("float32") / 255.0
x_train=x_train.reshape(-1, 28, 28, 1)
x_test=x_test.reshape(-1, 28, 28, 1)

model = keras.Sequential(
    [
        keras.Input(shape=(28, 28, 1)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax"),
    ]
)

model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.1)

loss,accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy:.4f}")

y_pred=np.argmax(model.predict(x_test), axis=1)

cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 91ms/step - accuracy: 0.7534 - loss: 0.7743 - val_accuracy: 0.9763 - val_loss: 0.0854
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 94ms/step - accuracy: 0.9613 - loss: 0.1252 - val_accuracy: 0.9843 - val_loss: 0.0568
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 47s 112ms/step - accuracy: 0.9741 - loss: 0.0870 - val_accuracy: 0.9867 - val_loss: 0.0495
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 103ms/step - accuracy: 0.9782 - loss: 0.0714 - val_accuracy: 0.9873 - val_loss: 0.0464
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 107ms/step - accuracy: 0.9803 - loss: 0.0623 - val_accuracy: 0.9892 - val_loss: 0.0385
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 39s 92ms/step - accuracy: 0.9819 - loss: 0.0581 - val_accuracy: 0.9907 - val_loss: 0.0344
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.9843 - loss: 0.0504 - val_accuracy: 0.9902 - val_loss: 0.0334
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 91ms/step - accuracy: 0.9850 - loss: 0.0492 - val_accuracy: 0.9912 - val_loss: 0.0322
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - accuracy: 0.9868 - loss: 0.0422 - val_accuracy: 0.9922 - val_loss: 0.0309
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.9861 - loss: 0.0423 - val_accuracy: 0.9912 - val_loss: 0.0299
# Test loss: 0.0261
# Test accuracy: 0.9907
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
import matplotlib.pyplot as plt

algorithms = ['KNN','SVM','Logistic Regression','Decision Trees','CNN']
accuracies = [0.9705, 0.9165, 0.9200, 0.8776, 0.9907]
accuracies_percent = [acc * 100 for acc in accuracies]

plt.figure(figsize=(10, 6))
bars = plt.bar(algorithms, accuracies_percent, color=['skyblue', 'orange', 'green', 'red', 'purple'])

for bar, acc in zip(bars, accuracies_percent):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{acc:.2f}%', ha='center', va='bottom')

plt.title('Test Accuracy Comparison of ML Algorithms', fontsize=14)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.ylim(0, 100)
plt.yticks(range(0, 101, 10))
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.show()

plt.figure(figsize=(10, 6))
plt.plot(algorithms, accuracies_percent, marker='o', linestyle='-', color='teal', linewidth=2)


for i, acc in enumerate(accuracies_percent):
    plt.text(i, acc + 1, f'{acc:.2f}%', ha='center', fontsize=10)

plt.title('Test Accuracy Comparison of ML Algorithms', fontsize=14)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.ylim(50, 100)
plt.yticks(range(50, 101, 10))
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
